# %%
import datetime 
import time

import pandas as pd
import pandas_ta as ta
from alpaca.data import CryptoHistoricalDataClient, StockHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest,StockBarsRequest
import credentials as cs
from alpaca.data.timeframe import TimeFrame
from datetime import datetime
api_key = cs.api_key
secret_key = cs.secret_key

from alpaca.trading.client import *
from alpaca.trading.requests import *
paper = True # Please do not modify this. This example is for paper trading only.
####

# Below are the variables for development this documents
# Please do not change these variables
trade_api_url = None
trade_api_wss = None
data_api_url = None
stream_data_wss = None
tickers = ["BTC/USD",'ETH/USD']
# setup clients
trade_client = TradingClient(api_key=api_key, secret_key=secret_key, paper=paper, url_override=trade_api_url)

# %% [markdown]
# # positions

# %%
positions = trade_client.get_all_positions()
positions
# Out:
# []

# %%
# Convert positions to DataFrame
df=pd.DataFrame([dict(position) for position in positions])
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dict(positions[0])
# Out:
# {'asset_id': UUID('64bbff51-59d6-4b3c-9351-13ad85e3c752'),
#  'symbol': 'BTCUSD',
#  'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#  'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#  'asset_marginable': False,
#  'avg_entry_price': '66232.809592542',
#  'qty': '0.009991395',
#  'side': <PositionSide.LONG: 'long'>,
#  'market_value': '666.61578309105007993116',
#  'cost_basis': '661.758162599',
#  'unrealized_pl': '4.85762049205007993116',
#  'unrealized_plpc': '0.0073404768790039',
#  'unrealized_intraday_pl': '4.85762049217390384116',
#  'unrealized_intraday_plpc': '0.0073404768791924',
#  'current_price': '66718.990000000008',
#  'lastday_price': '66191.9',
#  'change_today': '0.0079630589241283',
#  'swap_rate': None,
#  'avg_entry_swap_rate': None,
#  'usd': None,
#  'qty_available': '0.009991395'}

# %%
pd.DataFrame(positions,columns=dict(positions[0]).keys())
# Out:
#                                            asset_id            symbol  \
# 0  (asset_id, 64bbff51-59d6-4b3c-9351-13ad85e3c752)  (symbol, BTCUSD)
#
#                            exchange                       asset_class  \
# 0  (exchange, AssetExchange.CRYPTO)  (asset_class, AssetClass.CRYPTO)
#
#             asset_marginable                     avg_entry_price  \
# 0  (asset_marginable, False)  (avg_entry_price, 66232.809592542)
#
#                   qty                       side  \
# 0  (qty, 0.009991395)  (side, PositionSide.LONG)
#
#                       market_value                   cost_basis  ...  \
# 0  (market_value, 660.53941630785)  (cost_basis, 661.758162599)  ...
#
#                           unrealized_plpc  \
# 0  (unrealized_plpc, -0.0018416792720221)
#
#                            unrealized_intraday_pl  \
# 0  (unrealized_intraday_pl, -1.21874629102617609)
#
#                           unrealized_intraday_plpc              current_price  \
# 0  (unrealized_intraday_plpc, -0.0018416792718353)  (current_price, 66110.83)
#
#                 lastday_price                         change_today  \
# 0  (lastday_price, 66463.093)  (change_today, -0.0053001295019478)
#
#            swap_rate          avg_entry_swap_rate          usd  \
# 0  (swap_rate, None)  (avg_entry_swap_rate, None)  (usd, None)
#
#                   qty_available
# 0  (qty_available, 0.009991395)
#
# [1 rows x 21 columns]

# %%
# see all open orders
req = GetOrdersRequest(
    status = QueryOrderStatus.ALL,
    symbols = tickers
)
open_orders = trade_client.get_orders(req)
open_orders
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'canceled_at': datetime.datetime(2024, 6, 15, 14, 45, 2, 749464, tzinfo=TzInfo(UTC)),
#      'client_order_id': '63c3e2fb-9037-4c38-bfbb-16ca0e3e7420',
#      'created_at': datetime.datetime(2024, 6, 15, 14, 44, 3, 377102, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('69de61c6-337d-4f85-b614-06fee1f54c68'),
#      'legs': None,
#      'limit_price': '60000',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'qty': '0.01',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.CANCELED: 'canceled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 6, 15, 14, 44, 3, 377102, tzinfo=TzInfo(UTC)),
#      'symbol': 'BTC/USD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.LIMIT: 'limit'>,
#      'updated_at': datetime.datetime(2024, 6, 15, 14, 45, 2, 776556, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'canceled_at': datetime.datetime(2024, 6, 15, 14, 45, 2, 749571, tzinfo=TzInfo(UTC)),
#      'client_order_id': '2f37176c-3abd-45cb-abbd-e405b8049ae2',
#      'created_at': datetime.datetime(2024, 6, 15, 14, 43, 59, 64905, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('942a9675-9d8a-444a-9188-8c008e80ebee'),
#      'legs': None,
#      'limit_price': '55000',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'qty': '0.01',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.CANCELED: 'canceled'>,
#      'stop_price': '60000',
#      'submitted_at': datetime.datetime(2024, 6, 15, 14, 44, 0, 40403, tzinfo=TzInfo(UTC)),
#      'symbol': 'BTC/USD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'updated_at': datetime.datetime(2024, 6, 15, 14, 45, 2, 776618, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'canceled_at': datetime.datetime(2024, 6, 15, 14, 42, 24, 163546, tzinfo=TzInfo(UTC)),
#      'client_order_id': '2b5761c0-285e-40e9-be45-cb57be2ccb57',
#      'created_at': datetime.datetime(2024, 6, 15, 14, 41, 28, 4789, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('9242e34a-913f-4c83-9a98-5b87cb5bc613'),
#      'legs': None,
#      'limit_price': '55000',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'qty': '0.01',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.CANCELED: 'canceled'>,
#      'stop_price': '60000',
#      'submitted_at': datetime.datetime(2024, 6, 15, 14, 42, 9, 599089, tzinfo=TzInfo(UTC)),
#      'symbol': 'BTC/USD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'updated_at': datetime.datetime(2024, 6, 15, 14, 42, 24, 176585, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'canceled_at': datetime.datetime(2024, 6, 15, 14, 40, 49, 874121, tzinfo=TzInfo(UTC)),
#      'client_order_id': 'ab81850b-5bb6-4a4b-a7ef-a1a524204c01',
#      'created_at': datetime.datetime(2024, 6, 15, 14, 39, 54, 942233, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('685328c3-3778-4c28-8007-1dd7445b6973'),
#      'legs': None,
#      'limit_price': '60000',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'qty': '0.01',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.CANCELED: 'canceled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 6, 15, 14, 39, 54, 942233, tzinfo=TzInfo(UTC)),
#      'symbol': 'BTC/USD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.LIMIT: 'limit'>,
#      'updated_at': datetime.datetime(2024, 6, 15, 14, 40, 49, 927170, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'canceled_at': None,
#      'client_order_id': 'ec77104d-2a82-4828-8da2-5ce7b6f4fe4f',
#      'created_at': datetime.datetime(2024, 6, 15, 14, 38, 39, 175964, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 6, 15, 14, 38, 39, 179322, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '66208.225',
#      'filled_qty': '0.000016437',
#      'hwm': None,
#      'id': UUID('539876c9-14df-4ea3-8e36-da8ef9de6c66'),
#      'legs': None,
#      'limit_price': None,
#      'notional': '1.11',
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': None,
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 6, 15, 14, 38, 39, 175964, tzinfo=TzInfo(UTC)),
#      'symbol': 'BTC/USD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 6, 15, 14, 38, 39, 227308, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'canceled_at': None,
#      'client_order_id': '4a861c58-5b79-4a1c-987b-067e23077f93',
#      'created_at': datetime.datetime(2024, 6, 15, 14, 37, 17, 644729, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 6, 15, 14, 37, 17, 647436, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '66232.85',
#      'filled_qty': '0.01',
#      'hwm': None,
#      'id': UUID('7df2d9bc-052f-4062-aeee-2c1dd7c25880'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '0.01',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 6, 15, 14, 37, 17, 644729, tzinfo=TzInfo(UTC)),
#      'symbol': 'BTC/USD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 6, 15, 14, 37, 17, 677332, tzinfo=TzInfo(UTC))}]

# %%
pd.DataFrame([dict(position) for position in open_orders])
# Out:
#                                      id                       client_order_id  \
# 0  69de61c6-337d-4f85-b614-06fee1f54c68  63c3e2fb-9037-4c38-bfbb-16ca0e3e7420
# 1  942a9675-9d8a-444a-9188-8c008e80ebee  2f37176c-3abd-45cb-abbd-e405b8049ae2
# 2  9242e34a-913f-4c83-9a98-5b87cb5bc613  2b5761c0-285e-40e9-be45-cb57be2ccb57
# 3  685328c3-3778-4c28-8007-1dd7445b6973  ab81850b-5bb6-4a4b-a7ef-a1a524204c01
# 4  539876c9-14df-4ea3-8e36-da8ef9de6c66  ec77104d-2a82-4828-8da2-5ce7b6f4fe4f
# 5  7df2d9bc-052f-4062-aeee-2c1dd7c25880  4a861c58-5b79-4a1c-987b-067e23077f93
#
#                         created_at                       updated_at  \
# 0 2024-06-15 14:44:03.377102+00:00 2024-06-15 14:45:02.776556+00:00
# 1 2024-06-15 14:43:59.064905+00:00 2024-06-15 14:45:02.776618+00:00
# 2 2024-06-15 14:41:28.004789+00:00 2024-06-15 14:42:24.176585+00:00
# 3 2024-06-15 14:39:54.942233+00:00 2024-06-15 14:40:49.927170+00:00
# 4 2024-06-15 14:38:39.175964+00:00 2024-06-15 14:38:39.227308+00:00
# 5 2024-06-15 14:37:17.644729+00:00 2024-06-15 14:37:17.677332+00:00
#
#                       submitted_at                        filled_at  \
# 0 2024-06-15 14:44:03.377102+00:00                              NaT
# 1 2024-06-15 14:44:00.040403+00:00                              NaT
# 2 2024-06-15 14:42:09.599089+00:00                              NaT
# 3 2024-06-15 14:39:54.942233+00:00                              NaT
# 4 2024-06-15 14:38:39.175964+00:00 2024-06-15 14:38:39.179322+00:00
# 5 2024-06-15 14:37:17.644729+00:00 2024-06-15 14:37:17.647436+00:00
#
#   expired_at                      canceled_at failed_at replaced_at  ...  \
# 0       None 2024-06-15 14:45:02.749464+00:00      None        None  ...
# 1       None 2024-06-15 14:45:02.749571+00:00      None        None  ...
# 2       None 2024-06-15 14:42:24.163546+00:00      None        None  ...
# 3       None 2024-06-15 14:40:49.874121+00:00      None        None  ...
# 4       None                              NaT      None        None  ...
# 5       None                              NaT      None        None  ...
#
#             side    time_in_force limit_price stop_price  \
# 0  OrderSide.BUY  TimeInForce.GTC       60000       None
# 1  OrderSide.BUY  TimeInForce.GTC       55000      60000
# 2  OrderSide.BUY  TimeInForce.GTC       55000      60000
# 3  OrderSide.BUY  TimeInForce.GTC       60000       None
# 4  OrderSide.BUY  TimeInForce.GTC        None       None
# 5  OrderSide.BUY  TimeInForce.GTC        None       None
#
#                  status extended_hours  legs trail_percent trail_price   hwm
# 0  OrderStatus.CANCELED          False  None          None        None  None
# 1  OrderStatus.CANCELED          False  None          None        None  None
# 2  OrderStatus.CANCELED          False  None          None        None  None
# 3  OrderStatus.CANCELED          False  None          None        None  None
# 4    OrderStatus.FILLED          False  None          None        None  None
# 5    OrderStatus.FILLED          False  None          None        None  None
#
# [6 rows x 32 columns]

# %%
# check trading account
# You can check definition of each field in the following documents
# ref. https://docs.alpaca.markets/docs/account-plans
# ref. https://docs.alpaca.markets/reference/getaccount-1
acct = trade_client.get_account()
acct
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA3JL9EDDPLL',
#     'accrued_fees': '0',
#     'buying_power': '198671.16',
#     'cash': '99335.58',
#     'created_at': datetime.datetime(2023, 5, 26, 10, 24, 2, 366956, tzinfo=TzInfo(UTC)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '100002.2',
#     'id': UUID('09818092-d381-4bcf-a941-8f1ec2ae82c0'),
#     'initial_margin': '0',
#     'last_equity': '99999',
#     'last_maintenance_margin': '0',
#     'long_market_value': '666.62',
#     'maintenance_margin': '0',
#     'multiplier': '2',
#     'non_marginable_buying_power': '99335.58',
#     'options_approved_level': 2,
#     'options_buying_power': '99335.58',
#     'options_trading_level': 2,
#     'pattern_day_trader': True,
#     'pending_transfer_in': '0',
#     'pending_transfer_out': None,
#     'portfolio_value': '100002.2',
#     'regt_buying_power': '198671.16',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '99999',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}
